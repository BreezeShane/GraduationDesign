# %%
# !rm -rf "/hy-tmp/log/"
# !mkdir "/hy-tmp/log/"

# %%
# !rm -rf "/hy-tmp/models/"
# !mkdir "/hy-tmp/models/"

# %%
#!rm -rf "./IP102_v1.1/"

# %%
!7z x "/hy-tmp/dataset.7z" -o"/hy-tmp/"
!7z x "/hy-tmp/dl_svc.7z" -o"/hy-tmp/"
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,8 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 3105031916 bytes (2962 MiB)
#
# Extracting archive: /content/gdrive/MyDrive/GraduationDesign/dataset.7z
# --
# Path = /content/gdrive/MyDrive/GraduationDesign/dataset.7z
# Type = 7z
# Physical Size = 3105031916
# Headers Size = 529063
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 2
# Files: 75227
# Size:       3193077659
# Compressed: 3105031916

# %%
# !pip install -r /hy-tmp/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 82.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 24.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 92.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 MB 33.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 36.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...

# %%
# !nvidia-smi
# Out:
# Wed May  8 14:13:37 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !python /hy-tmp/manager.py -h
# Out:
# [2024-05-08 09:34:04,291] [INFO] [real_accelerator.py:191:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 2024-05-08 09:34:06.299491: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-08 09:34:06.299571: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-08 09:34:06.302292: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-08 09:34:07.462741: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# usage: manager.py [-h] [--use_lora] [--gpu_id GPU_ID] [--load_model_path MOD_LOC]
# ...

# %%
# !python /content/gdrive/MyDrive/GraduationDesign/manager.py train \
  --tset "/hy-tmp/IP102_v1.1/" \
  --text "/hy-tmp/IP102_v1.1" \
  --vset "/hy-tmp/IP102_v1.1/" \
  --device 0 \
  --save_model_path "/hy-tmp/models"
# Out:
# [2024-05-08 16:07:21,907] [INFO] [real_accelerator.py:191:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 2024-05-08 16:07:23.743818: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-08 16:07:23.743872: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-08 16:07:23.745326: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-08 16:07:24.852266: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Layer (type:depth-idx)                                       Output Shape              Param #
# ...

# %%
# !python /content/gdrive/MyDrive/GraduationDesign/manager.py train \
  --use_lora \
  --tset "/hy-tmp/IP102_v1.1/" \
  --text "/hy-tmp/IP102_v1.1" \
  --vset "/hy-tmp/IP102_v1.1/" \
  --device 0 \
  --save_model_path "/hy-tmp/models"

# %%
# !python /content/gdrive/MyDrive/GraduationDesign/manager.py train \
  --use_deepspeed \
  --tset "/hy-tmp/IP102_v1.1/" \
  --text "/hy-tmp/IP102_v1.1" \
  --vset "/hy-tmp/IP102_v1.1/" \
  --device 0 \
  --save_model_path "/hy-tmp/models"

# %%
# !python /content/gdrive/MyDrive/GraduationDesign/manager.py train \
  --use_lora \
  --use_deepspeed \
  --tset "/hy-tmp/IP102_v1.1/" \
  --text "/hy-tmp/IP102_v1.1" \
  --vset "/hy-tmp/IP102_v1.1/" \
  --device 0 \
  --save_model_path "/hy-tmp/models"

# %%
# !cp -r /tf_logs /hy-tmp/log

# %%
# !oss cp /hy-tmp/models oss://models
# !oss cp /hy-tmp/log oss://log
